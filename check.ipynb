# %%
import pandas as pd

# %%
df = pd.read_csv('kitaptar_search_results.csv')
df
# Out:
#                                                  query message_ids  num_hits  \
# 0          Динис Бүләков Оса ҡыр ҡаҙҙары Хәким Хәйретд         757         0
# 1       Тәнзилә Дәүләтбирҙина Тирмә Миңзәлә Хәйруллина         754         0
# 2                   Рәшит Шәкүр Сана юлы Хәмит Яруллин         752         0
# 3     Нәжиә Игеҙйәнова Туй күлдәге Илһөйәр Ғәзетдинова         750         0
# 4          Динис Исламов Оҙатыу Наилә Ғәләүетдинова уҡ         748         0
# ..                                                 ...         ...       ...
# 574  Айгиз Баймөхәмәтов Ҡалдырма, әсәй Альберт Имам...          10         0
# 575                      Мостай Кәрим Аҡ оя Олег Ханов           9         0
# 576  Ибраһим Ғиззәтуллин Булат ҡоросо Хәким Хәйретд...           8         0
# 577  Ибраһим Ғиззәтуллин Үлгәндән һуң 30 йыл 1,2 өл...           4         0
# 578    Тимерғәле Килмөхәмәтов Урман моңо Илдар Ғүмәров           3         0
#
# ...

# %%
df.best_match_title.value_counts()
# Out:
# best_match_title
# Әҫәрҙәр 5 том                                                                   2
# Йәшел сирәмдә һары керәндил                                                     1
# Литературное чтение для 2-го класса.Ч.2_Сынбулатова,Давлетшина.2014             1
# Буренушка                                                                       1
# Аҡман-тоҡман                                                                    1
# Ҡарат                                                                           1
# Ҡыҙыҡлы осрашыуҙар                                                              1
# Хәтерҙәге яҡты миҙгелдәр                                                        1
# Сөләймән Мырҙабулатов: заманы һәм көрәше. Тәүәрих-публицистика (1917 — 1922)    1
# Ҡурсаулыҡ һуҡмаҡтарында                                                         1
# Башкирский народный транспорт. XIX-начало XX в. Уфа. 1992                       1
# ...
